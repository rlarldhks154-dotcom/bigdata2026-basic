# %% [markdown]
# # 리스트의 for문

# %%
pandas = ['러바오', '아이바오', '푸바오', '루이바오', '후이바오']

# %%
for p in pandas:
    print(p)
# Out:
# 러바오
# 아이바오
# 푸바오
# 루이바오
# 후이바오

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# # enumerate 함수
#
# for 인덱스번호, 값 in enumerate(컬렉션 자료형):
#     pass

# %%
for p in enumerate(pandas):
    print(p)
# Out:
# (0, '러바오')
# (1, '아이바오')
# (2, '푸바오')
# (3, '루이바오')
# (4, '후이바오')

# %% [markdown]
# ## 튜플 언패킹
#
# 각각의 변수에 튜플의 값을 쪼개 담는다

# %%
i = p[0]

# %%
name = p[1]

# %%
i, name
# Out:
# (4, '후이바오')

# %%
for index, name in enumerate(pandas):
    print(index)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for index, name in enumerate(pandas):
    print(index,name)
# Out:
# 0 러바오
# 1 아이바오
# 2 푸바오
# 3 루이바오
# 4 후이바오

# %%
for index, name in enumerate(pandas):
    print(f'{index+1}번째 판다 {name}')
# Out:
# 1번째 판다 러바오
# 2번째 판다 아이바오
# 3번째 판다 푸바오
# 4번째 판다 루이바오
# 5번째 판다 후이바오

# %%
for index, name in enumerate(pandas,start=1):
    print(f'{index}번째 판다 {name}')
# Out:
# 1번째 판다 러바오
# 2번째 판다 아이바오
# 3번째 판다 푸바오
# 4번째 판다 루이바오
# 5번째 판다 후이바오
