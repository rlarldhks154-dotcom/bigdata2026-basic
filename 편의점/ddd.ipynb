# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('IF0039.csv')

# %%
df
# Out:
#        ctprvn_cd  objt_id  fclty_cd  data_yr      emd_cd       fclty_nm  \
# 0            NaN   196003    509010     2025         NaN   세븐일레븐원주단구로또점
# 1           41.0   196004    509010     2025  41480102.0        이마트24면산
# 2           42.0   196005    509010     2025  42190101.0         GS25태백
# 3           42.0   196006    509010     2025  42210101.0     지에스25속초영랑점
# 4           41.0   196007    509010     2025  41220103.0          코아루마트
# ...          ...      ...       ...      ...         ...            ...
# 54337       44.0   250340    509010     2025  44210390.0       씨유서산한서대점
# 54338       44.0   250341    509010     2025  44200114.0        세븐일레븐아산
# 54339       43.0   250342    509010     2025  43130335.0  세븐일레븐충주교통대카페점
# 54340       43.0   250343    509010     2025  43112102.0       지에스25충북대
# 54341       43.0   250344    509010     2025  43770350.0         늘푸른편의점
#
#        telno                  rn_adres   sgg_cd fclty_ty            x  \
# ...
