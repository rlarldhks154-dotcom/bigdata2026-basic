# %% [markdown]
# # 🚌 대구버스 공공데이터 API 실습 워크시트
#
# **목표:** 공공데이터포털 API 문서를 읽고, 직접 데이터를 불러와봅니다.
#
# ---
# ## ✅ 시작 전 체크리스트
# - [ ] 공공데이터포털 회원가입 완료
# - [ ] 대구버스정보시스템 API 활용 신청 완료
# - [ ] API 키 승인 완료 (마이페이지 > 활용신청 현황에서 확인)
#
# > 📌 API 페이지 주소: https://www.data.go.kr/data/15139134/openapi.do

# %% [markdown]
# ---
# ## 📖 Step 0. API가 뭔가요?
#
# **API(Application Programming Interface)** 는 프로그램끼리 데이터를 주고받는 약속된 방법입니다.
#
# ```
# 🙋 나(파이썬 코드)
#       ↓ requests.get() 으로 요청
# 🏢 공공데이터 서버
#       ↓ JSON 데이터로 응답
# 📦 데이터 수신!
# ```
#
# ### 응답 코드 의미
# | 코드 | 의미 |
# |------|------|
# | **200** | ✅ 성공! |
# | **401** | 🔴 API 키 오류 |
# | **400** | 🔴 파라미터 오류 |
# | **500** | 🔴 서버 오류 |

# %% [markdown]
# ---
# ## 🔑 Step 1. API 키 설정
#
# 공공데이터포털 마이페이지에서 발급받은 **일반 인증키(Decoding)** 를 입력하세요.
#
# > ⚠️ 주의: 키 앞뒤에 공백이나 탭이 들어가면 401 오류가 납니다! `.strip()` 필수!

# %%
import nest_asyncio
import os
from dotenv import load_dotenv

nest_asyncio.apply()

load_dotenv()

API_KEY = os.getenv('OPENAPI_API_KEY')

# %%
import requests
import json


print("API 키 길이:", len(API_KEY))
print("앞 10자리:", API_KEY[:10], "...")
# Out:
# API 키 길이: 64
# 앞 10자리: 6ea6e6c0aa ...

# %% [markdown]
# ---
# ## 📡 Step 2. API 문서 읽기 연습
#
# 아래 사이트에서 **getBasic02** 항목을 찾아 다음을 채워보세요.
#
# 🌐 https://www.data.go.kr/data/15139134/openapi.do
#
# ### 📝 탐색 미션 (빈칸 채우기)
#
# ```
# 1. API 이름: getBasic02
# 2. 기능 설명: ___________________________
# 3. 필수 파라미터(*): ___________________________
# 4. 응답 데이터에 포함된 항목들:
#    - route (노선): routeId, routeNo, _____, _____
#    - bs (정류장): bsId, bsNm, _____, _____
#    - node (노드): nodeId, nodeNm, _____, _____
# ```

# %% [markdown]
# ---
# ## 🚀 Step 3. getBasic02 호출하기 (전체 기초 데이터)

# %%
# 📡 API 주소
url = "https://apis.data.go.kr/6270000/dbmsapi02/getBasic02"

# 📋 요청 파라미터
params = {
    "serviceKey": API_KEY
}

# 🚀 요청 보내기
response = requests.get(url, params=params)

# ✅ 결과 확인
print("응답 코드:", response.status_code)

if response.status_code == 200:
    print("✅ 성공!")
elif response.status_code == 401:
    print("🔴 API 키를 확인하세요!")
else:
    print("🔴 오류:", response.status_code)
# Out:
# 응답 코드: 200
# ✅ 성공!

# %% [markdown]
# ---
# ## 🔍 Step 4. 응답 데이터 구조 탐색

# %%
# JSON으로 변환
data = response.json()

# 전체 키 확인
print("최상위 키:", list(data.keys()))
# Out:
# 최상위 키: ['header', 'body']

# %%
# 헤더 확인 (성공 여부)
header = data["header"]
print("성공 여부:", header["success"])
print("결과 메시지:", header["resultMsg"])
print("결과 코드:", header["resultCode"])
# Out:
# 성공 여부: True
# 결과 메시지: 성공
# 결과 코드: 0000

# %%
# 바디 확인 (실제 데이터)
body = data["body"]
print("총 데이터 수:", body["totalCount"])
print("items 키 목록:", list(body["items"].keys()))
# Out:
# 총 데이터 수: 25172
# items 키 목록: ['bs', 'node', 'route', 'link']

# %% [markdown]
# ---
# ## 🚌 Step 5. 노선 정보 꺼내기

# %%
# 노선 데이터
routes = data["body"]["items"]["route"]

print(f"전체 노선 수: {len(routes)}개")
print("\n첫 번째 노선 정보:")
print(json.dumps(routes[0], ensure_ascii=False, indent=2))
# Out:
# 전체 노선 수: 522개
#
# 첫 번째 노선 정보:
# {
#   "routeId": "4050003000",
#   "routeNo": "동구3",
#   "routeNote": "부동방면",
#   "routeTCd": "4",
#   "stBsId": "7021051300",
#   "edBsId": "7011030000",
#   "stNm": "칠성시장",
#   "edNm": "부동",
#   "dirRouteNote": "부동",
#   "ndirRouteNote": "칠성시장",
#   "dataconnareacd": "DG"
# }

# %%
# 노선 번호만 출력 (앞 10개)
print("노선 번호 목록 (앞 10개):")
for route in routes[:10]:
    print(f"  - {route['routeNo']} ({route['stNm']} → {route['edNm']})")
# Out:
# 노선 번호 목록 (앞 10개):
#   - 동구3 (칠성시장 → 부동)
#   - 504 (방천리 → 두리봉터널)
#   - 232-1 (방천리 → 방천리)
#   - 403 (범물동 → 조야동)
#   - 405 (삼산리 → 방천리)
#   - 413 (대일리 → 종합유통단지)
#   - 503 (연경동 → 성서산업단지)
#   - 706 (관음동 → 대곡지구)
#   - 708 (동호동(북구) → 동호지구)
#   - 719 (관음동 → 금구리)

# %% [markdown]
# ### 🎯 미션 1
# 아래 코드를 완성해서 **급행** 노선만 출력해보세요!

# %%
# 🎯 미션 1: 급행 노선만 찾기
print("급행 노선 목록:")
for route in routes:
    if "급행" in route["routeNo"]:   # ← 이 조건을 바꿔보세요!
        print(f"  🚌 {route['routeNo']} | {route['stNm']} → {route['edNm']}")
# Out:
# 급행 노선 목록:
#   🚌 급행8 | 달성2차산업단지 → 서대구역
#   🚌 급행8-1 | 유곡리 → 진천역
#   🚌 급행9 | 동호동 → 군위군청
#   🚌 급행9-2 | 동호동 → 삼국유사면문화관
#   🚌 급행2 | 냉천리 → 동호동(북구)
#   🚌 급행10 | 대천동 → 반야월역
#   🚌 급행9-3 | 동호동 → 소보시장
#   🚌 급행9-1 | 동호동 → 우보정류장
#   🚌 급행5 | 성서산업단지 → 대구대
#   🚌 급행7 | 대곡동(공영차고지) → 동호동
#   🚌 급행1 | 동화사 → 동대구역
#   🚌 급행1 | 동화사 → 매곡
#   🚌 급행3 | 범물동 → 동명면

# %% [markdown]
# ---
# ## 🚏 Step 6. 정류장 정보 꺼내기

# %%
# 정류장 데이터
stops = data["body"]["items"]["bs"]

print(f"전체 정류장 수: {len(stops)}개")
print("\n첫 번째 정류장 정보:")
print(json.dumps(stops[0], ensure_ascii=False, indent=2))
# Out:
# 전체 정류장 수: 5913개
#
# 첫 번째 정류장 정보:
# {
#   "bsId": "7041000100",
#   "bsNm": "한국방송통신대학교건너",
#   "xPos": 128.49331521666667,
#   "yPos": 35.859160116666665,
#   "wincId": "01153"
# }

# %% [markdown]
# ### 🎯 미션 2
# 아래 빈칸을 채워서 **"동대구역"** 이 이름에 포함된 정류장을 모두 출력해보세요!

# %%
# 🎯 미션 2: 동대구역 정류장 찾기
keyword = "동대구역"   # ← 원하는 키워드로 바꿔보세요

print(f"'{keyword}' 포함 정류장:")
for stop in stops:
    if keyword in stop["bsNm"]:   # ← 빈칸: 정류장 이름 필드명은?
        print(f"  🚏 {stop['bsNm']} | ID: {stop['bsId']}")
# Out:
# '동대구역' 포함 정류장:
#   🚏 동대구역센트럴시티자이아파트 | ID: 7011003500
#   🚏 동대구역복합환승센터앞 | ID: 7011004000
#   🚏 동대구역복합환승센터건너 | ID: 7011004100
#   🚏 동대구역 | ID: 7011006700
#   🚏 동대구역건너 | ID: 7011006800
#   🚏 동대구역지하도1 | ID: 7011008000
#   🚏 동대구역지하도2 | ID: 7011008100
#   🚏 동대구역수화물취급소건너 | ID: 7011021200
#   🚏 동대구역수화물취급소앞 | ID: 7011021300
#   🚏 동대구역화성파크드림 | ID: 7011006900
#   🚏 동대구역(2번출구)건너 | ID: 7011067300

# %% [markdown]
# ---
# ## 🔗 Step 7. 다른 API 탐색하기
#
# API 문서 페이지에서 다른 API들을 찾아 탐색해봅시다.
#
# ### 📝 탐색 미션 (빈칸 채우기)
#
# | API 이름 | 기능 | 필수 파라미터 | 내가 뽑고 싶은 데이터 |
# |----------|------|--------------|---------------------|
# | getBasic02 | 기초종합 정보 | serviceKey | 노선/정류장 목록 |
# | getBs02 | ___________ | serviceKey, ________ | |
# | getRoute02 | ___________ | serviceKey, ________ | |
# | getRealtime02 | ___________ | serviceKey, ________ | |
# | getPos02 | ___________ | serviceKey, ________ | |

# %%
# 🎯 미션 3: getBs02 - 정류장 상세 정보 조회
# Step 6에서 찾은 정류장 ID를 활용해보세요!

url_bs = "https://apis.data.go.kr/6270000/dbmsapi02/getBs02"

params_bs = {
    "serviceKey": API_KEY,
    "routeId": "4050003000"   # ← Step 6에서 찾은 bsId 입력
}

response_bs = requests.get(url_bs, params=params_bs)
print("응답 코드:", response_bs.status_code)

if response_bs.status_code == 200:
    data_bs = response_bs.json()
    print(json.dumps(data_bs, ensure_ascii=False, indent=2))
# Out:
# 응답 코드: 200
# {
#   "header": {
#     "success": true,
#     "resultCode": "0000",
#     "resultMsg": "성공"
#   },
#   "body": {
#     "items": [
#       {
#         "bsId": "7011030000",
#         "bsNm": "부동(종점)",
#         "xPos": 128.69484815,
#         "yPos": 35.8892428,
#         "moveDir": "0",
#         "seq": "1"
#       },
#       {
#         "bsId": "7011029800",
#         "bsNm": "부동",
#         "xPos": 128.67890371666667,
#         "yPos": 35.88824445,
#         "moveDir": "0",
#         "seq": "2"
#       },
#       {
#         "bsId": "7011020600",
#         "bsNm": "방촌빌라",
#         "xPos": 128.67153825,
#         "yPos": 35.881684033333336,
#         "moveDir": "0",
#         "seq": "3"
#       },
#       {
#         "bsId": "7011027500",
#         "bsNm": "대구선방촌공원남편",
#         "xPos": 128.66960148333334,
#         "yPos": 35.88033175,
#         "moveDir": "0",
#         "seq": "4"
#       },
#       {
#         "bsId": "7011016300",
#         "bsNm": "방촌시장건너",
#         "xPos": 128.66601351666668,
#         "yPos": 35.881309216666665,
#         "moveDir": "0",
#         "seq": "5"
#       },
#       {
#         "bsId": "7011016500",
#         "bsNm": "퀸벨호텔건너",
#         "xPos": 128.66183418333333,
#         "yPos": 35.883222333333336,
#         "moveDir": "0",
#         "seq": "6"
#       },
#       {
#         "bsId": "7011016700",
#         "bsNm": "해안역(1번출구)",
#         "xPos": 128.65940903333333,
#         "yPos": 35.883686266666665,
#         "moveDir": "0",
#         "seq": "7"
#       },
#       {
#         "bsId": "7011016900",
#         "bsNm": "홈플러스동촌점앞",
#         "xPos": 128.6560563,
#         "yPos": 35.88526353333334,
#         "moveDir": "0",
#         "seq": "8"
#       },
#       {
#         "bsId": "7011017100",
#         "bsNm": "동촌역(신길)1",
#         "xPos": 128.65276978333333,
#         "yPos": 35.88703493333333,
#         "moveDir": "0",
#         "seq": "9"
#       },
#       {
#         "bsId": "7011017300",
#         "bsNm": "동촌화성타운건너",
#         "xPos": 128.6478802,
#         "yPos": 35.8897939,
#         "moveDir": "0",
#         "seq": "10"
#       },
#       {
#         "bsId": "7011012100",
#         "bsNm": "입석중학교건너",
#         "xPos": 128.64564126666667,
#         "yPos": 35.89104095,
#         "moveDir": "0",
#         "seq": "11"
#       },
#       {
#         "bsId": "7011011900",
#         "bsNm": "아양교2",
#         "xPos": 128.64266895,
#         "yPos": 35.89072443333333,
#         "moveDir": "0",
#         "seq": "12"
#       },
#       {
#         "bsId": "7011011000",
#         "bsNm": "아양교역(1번출구)",
#         "xPos": 128.6394667,
#         "yPos": 35.88713726666667,
#         "moveDir": "0",
#         "seq": "13"
#       },
#       {
#         "bsId": "7011010700",
#         "bsNm": "동구청앞",
#         "xPos": 128.63457848333334,
#         "yPos": 35.8859654,
#         "moveDir": "0",
#         "seq": "14"
#       },
#       {
#         "bsId": "7011007500",
#         "bsNm": "신암4동행정복지센터건너",
#         "xPos": 128.62985648333333,
#         "yPos": 35.885699366666664,
#         "moveDir": "0",
#         "seq": "15"
#       },
#       {
#         "bsId": "7011007300",
#         "bsNm": "KT동대구지사건너",
#         "xPos": 128.62613503333333,
#         "yPos": 35.88463398333333,
#         "moveDir": "0",
#         "seq": "16"
#       },
#       {
#         "bsId": "7011009700",
#         "bsNm": "평화시장(닭똥집골목)앞",
#         "xPos": 128.62140661666666,
#         "yPos": 35.88277446666667,
#         "moveDir": "0",
#         "seq": "17"
#       },
#       {
#         "bsId": "7011009400",
#         "bsNm": "공고네거리1",
#         "xPos": 128.61597178333332,
#         "yPos": 35.881607366666664,
#         "moveDir": "0",
#         "seq": "18"
#       },
#       {
#         "bsId": "7021025000",
#         "bsNm": "강남약국건너",
#         "xPos": 128.61069261666665,
#         "yPos": 35.879995066666666,
#         "moveDir": "0",
#         "seq": "19"
#       },
#       {
#         "bsId": "7021024800",
#         "bsNm": "농협중앙회앞",
#         "xPos": 128.60718833333334,
#         "yPos": 35.877695,
#         "moveDir": "0",
#         "seq": "20"
#       },
#       {
#         "bsId": "7021029600",
#         "bsNm": "칠성시장역(서문프라자건너)",
#         "xPos": 128.60518106666666,
#         "yPos": 35.87618943333333,
#         "moveDir": "0",
#         "seq": "21"
#       },
#       {
#         "bsId": "7021024400",
#         "bsNm": "칠성시장(농협건너)",
#         "xPos": 128.60357233333335,
#         "yPos": 35.87734938333333,
#         "moveDir": "0",
#         "seq": "22"
#       },
#       {
#         "bsId": "7021024200",
#         "bsNm": "칠성시장(전자상가건너)",
#         "xPos": 128.60302856666667,
#         "yPos": 35.8787282,
#         "moveDir": "0",
#         "seq": "23"
#       },
#       {
#         "bsId": "7021023900",
#         "bsNm": "새동네아파트건너",
#         "xPos": 128.60180213333334,
#         "yPos": 35.88061315,
#         "moveDir": "0",
#         "seq": "24"
#       },
#       {
#         "bsId": "7021051300",
#         "bsNm": "칠성고가도로하단",
#         "xPos": 128.60145373333333,
#         "yPos": 35.881366916666664,
#         "moveDir": "0",
#         "seq": "25"
#       },
#       {
#         "bsId": "7021051300",
#         "bsNm": "칠성고가도로하단",
#         "xPos": 128.60145373333333,
#         "yPos": 35.881366916666664,
#         "moveDir": "1",
#         "seq": "1"
#       },
#       {
#         "bsId": "7021024100",
#         "bsNm": "칠성시장(전자상가앞)",
#         "xPos": 128.60269031666667,
#         "yPos": 35.8785328,
#         "moveDir": "1",
#         "seq": "2"
#       },
#       {
#         "bsId": "7021024300",
#         "bsNm": "칠성시장(농협앞)",
#         "xPos": 128.60345218333333,
#         "yPos": 35.877126616666665,
#         "moveDir": "1",
#         "seq": "3"
#       },
#       {
#         "bsId": "7021029500",
#         "bsNm": "칠성시장역(서문프라자앞)",
#         "xPos": 128.60507736666668,
#         "yPos": 35.8760227,
#         "moveDir": "1",
#         "seq": "4"
#       },
#       {
#         "bsId": "7011008800",
#         "bsNm": "신암2동우체국",
#         "xPos": 128.60792113333332,
#         "yPos": 35.87776641666667,
#         "moveDir": "1",
#         "seq": "5"
#       },
#       {
#         "bsId": "7011009000",
#         "bsNm": "강남약국앞2",
#         "xPos": 128.61138493333334,
#         "yPos": 35.88030968333333,
#         "moveDir": "1",
#         "seq": "6"
#       },
#       {
#         "bsId": "7011009300",
#         "bsNm": "공고네거리2",
#         "xPos": 128.61594515,
#         "yPos": 35.88140735,
#         "moveDir": "1",
#         "seq": "7"
#       },
#       {
#         "bsId": "7011009600",
#         "bsNm": "평화시장(닭똥집골목)건너",
#         "xPos": 128.62069091666666,
#         "yPos": 35.88239626666667,
#         "moveDir": "1",
#         "seq": "8"
#       },
#       {
#         "bsId": "7011007200",
#         "bsNm": "KT동대구지사앞",
#         "xPos": 128.62641995,
#         "yPos": 35.884559716666665,
#         "moveDir": "1",
#         "seq": "9"
#       },
#       {
#         "bsId": "7011007400",
#         "bsNm": "신암4동행정복지센터앞",
#         "xPos": 128.62994871666666,
#         "yPos": 35.885492666666664,
#         "moveDir": "1",
#         "seq": "10"
#       },
#       {
#         "bsId": "7011010600",
#         "bsNm": "동구청건너",
#         "xPos": 128.63479058333334,
#         "yPos": 35.88576565,
#         "moveDir": "1",
#         "seq": "11"
#       },
#       {
#         "bsId": "7011010900",
#         "bsNm": "아양교역(2번출구)",
#         "xPos": 128.63989796666667,
#         "yPos": 35.887059416666666,
#         "moveDir": "1",
#         "seq": "12"
#       },
#       {
#         "bsId": "7011011800",
#         "bsNm": "아양교1",
#         "xPos": 128.64286326666667,
#         "yPos": 35.890538666666664,
#         "moveDir": "1",
#         "seq": "13"
#       },
#       {
#         "bsId": "7011012000",
#         "bsNm": "입석중학교앞",
#         "xPos": 128.6449521,
#         "yPos": 35.891150466666666,
#         "moveDir": "1",
#         "seq": "14"
#       },
#       {
#         "bsId": "7011017400",
#         "bsNm": "동촌화성타운앞",
#         "xPos": 128.64706951666668,
#         "yPos": 35.88997106666667,
#         "moveDir": "1",
#         "seq": "15"
#       },
#       {
#         "bsId": "7011017200",
#         "bsNm": "동촌역(신길)2",
#         "xPos": 128.65110326666667,
#         "yPos": 35.88768783333333,
#         "moveDir": "1",
#         "seq": "16"
#       },
#       {
#         "bsId": "7011017000",
#         "bsNm": "홈플러스동촌점건너",
#         "xPos": 128.656223,
#         "yPos": 35.884873766666665,
#         "moveDir": "1",
#         "seq": "17"
#       },
#       {
#         "bsId": "7011016800",
#         "bsNm": "해안역(3번출구)",
#         "xPos": 128.6597315,
#         "yPos": 35.88341545,
#         "moveDir": "1",
#         "seq": "18"
#       },
#       {
#         "bsId": "7011016600",
#         "bsNm": "퀸벨호텔앞",
#         "xPos": 128.66226885,
#         "yPos": 35.88276425,
#         "moveDir": "1",
#         "seq": "19"
#       },
#       {
#         "bsId": "7011020500",
#         "bsNm": "농협방촌지점",
#         "xPos": 128.66564428333334,
#         "yPos": 35.88216678333333,
#         "moveDir": "1",
#         "seq": "20"
#       },
#       {
#         "bsId": "7011049200",
#         "bsNm": "대구선방촌공원",
#         "xPos": 128.66977666666668,
#         "yPos": 35.88083,
#         "moveDir": "1",
#         "seq": "21"
#       },
#       {
#         "bsId": "7011048400",
#         "bsNm": "해안동행정복지센터",
#         "xPos": 128.67233506666668,
#         "yPos": 35.8822944,
#         "moveDir": "1",
#         "seq": "22"
#       },
#       {
#         "bsId": "7011029900",
#         "bsNm": "부동삼거리",
#         "xPos": 128.67910166666667,
#         "yPos": 35.888551666666665,
#         "moveDir": "1",
#         "seq": "23"
#       },
#       {
#         "bsId": "7011030000",
#         "bsNm": "부동(종점)",
#         "xPos": 128.69484815,
#         "yPos": 35.8892428,
#         "moveDir": "1",
#         "seq": "24"
#       }
#     ],
#     "totalCount": 49
#   }
# }

# %% [markdown]
# ---
# ## 🏆 Step 8. 나만의 탐색 코드 작성
#
# 지금까지 배운 것을 활용해서 **내가 원하는 정보를 조회하는 코드**를 작성해보세요!
#
# **아이디어 예시:**
# - 집 근처 정류장 찾기
# - 특정 번호 버스의 출발지/도착지 확인
# - 정류장 이름에 '학교'가 들어가는 곳 찾기

# %%
# 🏆 나만의 탐색 코드
# 아이디어: ___________________________

# 여기에 코드를 작성하세요!

# %% [markdown]
# ---
# ## 📚 정리
#
# 오늘 배운 것:
#
# | 개념 | 코드 | 설명 |
# |------|------|------|
# | API 요청 | `requests.get(url, params=params)` | 서버에 데이터 요청 |
# | 응답 확인 | `response.status_code` | 200이면 성공 |
# | JSON 변환 | `response.json()` | 딕셔너리로 변환 |
# | 데이터 접근 | `data["body"]["items"]` | 키로 접근 |
# | 데이터 탐색 | `for item in items:` | 반복문으로 탐색 |
# | 조건 필터 | `if "키워드" in item["필드"]:` | 원하는 것만 추출 |
